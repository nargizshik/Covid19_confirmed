# %%
import plotly
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import csv

# %%
datcon = pd.read_csv('covid19_confirmed_global.csv')
datcon.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  3/21/22  3/22/22  3/23/22  \
# 0        0        0        0        0  ...   177191   177255   177321
# 1        0        0        0        0  ...   273088   273146   273164
# 2        0        0        0        0  ...   265562   265573   265585
# 3        0        0        0        0  ...    39234    39234    39713
# 4        0        0        0        0  ...    99010    99058    99058
#
#    3/24/22  3/25/22  3/26/22  3/27/22  3/28/22  3/29/22  3/30/22
# ...

# %%
datcon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Columns: 803 entries, Province/State to 3/30/22
# dtypes: float64(2), int64(799), object(2)
# memory usage: 1.7+ MB

# %%
df = pd.DataFrame(datcon, columns=datrec['Country/Region'])

# %%
datcon.describe()
# Out:
#               Lat        Long     1/22/20     1/23/20     1/24/20     1/25/20  \
# count  282.000000  282.000000  284.000000  284.000000  284.000000  284.000000
# mean    20.106368   21.958718    1.961268    2.313380    3.323944    5.059859
# std     25.841453   75.893366   26.402603   26.499491   32.992032   45.919425
# min    -71.949900 -178.116500    0.000000    0.000000    0.000000    0.000000
# 25%      4.643279  -22.036550    0.000000    0.000000    0.000000    0.000000
# 50%     21.607878   20.921188    0.000000    0.000000    0.000000    0.000000
# 75%     40.950592   84.992575    0.000000    0.000000    0.000000    0.000000
# max     71.706900  178.065000  444.000000  444.000000  549.000000  761.000000
#
#            1/26/20     1/27/20      1/28/20      1/29/20  ...       3/21/22  \
# count   284.000000   284.00000   284.000000   284.000000  ...  2.840000e+02
# mean      7.464789    10.31338    19.647887    21.721831  ...  1.662379e+06
# ...

# %%
for col in datcon.columns:
    print(col)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(df)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/extmath.py:985: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/extmath.py:990: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/extmath.py:1020: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction ** 2 / new_sample_count
# StandardScaler()

# %%
df_scaled = scaler.transform(df)

# %%
covid_df_last_week_columns =datcon.iloc[:,-8:].columns.to_list() 
covid_df_last_week_by_countries = datcon.iloc[:,[1]+[*range(-8,0,1)]] 
top=covid_df_last_week_by_countries.nlargest(n=10, columns=['3/30/22'])
print(top)
# Out:
#      Country/Region   3/23/22   3/24/22   3/25/22   3/26/22   3/27/22  \
# 256              US  79845757  79888474  79934877  79944197  79952518
# 148           India  43014687  43016372  43018032  43019453  43020723
# 31           Brazil  29738362  29775568  29809769  29839103  29849740
# 131          France  23822533  23962674  24101868  24241385  24351559
# 135         Germany  19278143  19596530  19893028  20145054  20256278
# 273  United Kingdom  20515998  20613817  20691123  20691123  20691123
# 218          Russia  17408475  17433393  17458275  17481799  17504537
# 255          Turkey  14743437  14760331  14775634  14789483  14800677
# 154           Italy  14070450  14153098  14229495  14304111  14364723
# 161    Korea, South  10822836  11162232  11497711  11815841  12003054
#
#       3/28/22   3/29/22   3/30/22
# 256  79995485  80019128  80057236
# 148  43021982  43023215  43024440
# 31   29857641  29887191  29920604
# 131  24376241  24583965  24751850
# ...

# %%
top.plot(x="Country/Region", y=["3/24/22", "3/25/22", "3/26/22","3/27/22","3/28/22","3/29/22","3/30/22"], kind="bar")

# %%
sns.barplot(x='Country/Region',y='3/23/22',data=top)
